# %% [markdown]
# <a href="https://colab.research.google.com/github/DEBADAS001KERNEL/END_TO_END_MACHINE_LEARNING_PROJECTS/blob/main/Crop_Type_Detection_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to Crop Type Detection Model:
#
# **The crop type detection model aims to predict the most suitable crop to be cultivated in a specific area based on various agricultural and environmental parameters. The model leverages machine learning techniques to analyze data on soil nutrients, climate conditions, and other factors, thus providing valuable insights for optimizing agricultural practices.**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d=pd.read_csv('/content/Crop_Recommendation (1).csv')

# %%
d.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop
# 0  202.935536  Rice
# 1  226.655537  Rice
# 2  263.964248  Rice
# 3  242.864034  Rice
# 4  262.717340  Rice

# %%
d['Crop'].value_counts() # or target column
# Out:
# Crop
# Rice           100
# Maize          100
# Jute           100
# Cotton         100
# Coconut        100
# Papaya         100
# Orange         100
# Apple          100
# Muskmelon      100
# Watermelon     100
# Grapes         100
# Mango          100
# Banana         100
# Pomegranate    100
# Lentil         100
# Blackgram      100
# MungBean       100
# MothBeans      100
# PigeonPeas     100
# KidneyBeans    100
# ChickPea       100
# Coffee         100
# Name: count, dtype: int64

# %%
d.shape
# Out:
# (2200, 8)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2200 non-null   int64
#  1   Phosphorus   2200 non-null   int64
#  2   Potassium    2200 non-null   int64
#  3   Temperature  2200 non-null   float64
#  4   Humidity     2200 non-null   float64
#  5   pH_Value     2200 non-null   float64
#  6   Rainfall     2200 non-null   float64
#  7   Crop         2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %% [markdown]
# **we can clearly see, that there is no catagorical column in the dataset**

# %%
c=['Nitrogen','Phosphorus','Potassium','Temperature', 'Humidity', 'pH_Value', 'Rainfall']

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
#histplot
for i in c:
  sns.histplot(d[i])
  plt.title(i)
  plt.show()

# %%
#boxplot[outliars]
for i in c:
  sns.boxplot(d[i])
  plt.title(i)
  plt.show()

# %%
# remove outliars

def remove_outliers(df, columns):
  for column in columns:
    # Calculate the interquartile range (IQR)
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1

    # Define the lower and upper bounds
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Replace outliers with the bounds
    df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)

  return df

# Remove outliers from the specified columns
d = remove_outliers(d, c)

# %%
for i in c:
  sns.boxplot(d[i])
  plt.title(i)
  plt.show()

# %%
 #duplicate rows remove

d.drop_duplicates(inplace=True)
d.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **let's see the big picture**

# %%
# !pip install ydata-profiling

import pandas as pd
from ydata_profiling import ProfileReport


# Generating the profile report
profile = ProfileReport(d)
profile.to_file(output_file="crops.html")
# Out:
# Requirement already satisfied: ydata-profiling in /usr/local/lib/python3.10/dist-packages (4.8.3)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.0.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.7.1)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.7.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (3.1.4)
# Requirement already satisfied: visions[type_image_path]<0.7.7,>=0.7.5 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.25.2)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.66.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.13.1)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from ydata-profiling) (0.58.1)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from imagehash==4.3.1->ydata-profiling) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<1,>=0.56.0->ydata-profiling) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.6.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.10/dist-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# **the name of the file is crops.html, check it in the file directory**

# %%
#  scatterplot

import matplotlib.pyplot as plt
for i in range(len(c)):
  for j in range(i+1, len(c)):
    sns.scatterplot(x=d[c[i]], y=d[c[j]])
    plt.show()

# %% [markdown]
# **preprocessing**

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
le=LabelEncoder()
d['Crop']=le.fit_transform(d['Crop'])

# %%
d.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42       43.0    20.879744  82.002744  6.502985
# 1        85          58       41.0    21.770462  80.319644  7.038096
# 2        60          55       44.0    23.004459  82.320763  7.840207
# 3        74          35       40.0    26.491096  80.158363  6.980401
# 4        78          42       42.0    20.130175  81.604873  7.628473
#
#      Rainfall  Crop
# 0  202.935536    20
# 1  213.841241    20
# 2  213.841241    20
# 3  213.841241    20
# 4  213.841241    20

# %%
# prompt: HEATMAP

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 7))
sns.heatmap(d.corr(), annot=True)
plt.show()

# %%
d['Crop'].value_counts()
# Out:
# Crop
# 20    100
# 11    100
# 8     100
# 6     100
# 4     100
# 17    100
# 16    100
# 0     100
# 15    100
# 21    100
# 7     100
# 12    100
# 1     100
# 19    100
# 10    100
# 2     100
# 14    100
# 13    100
# 18    100
# 9     100
# 3     100
# 5     100
# Name: count, dtype: int64

# %%
x=d.drop('Crop',axis=1)
y=d['Crop']

# %%
# prompt: traintest

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
s=StandardScaler()
x_train=s.fit_transform(x_train)
x_test=s.transform(x_test)

# %%
y_train
# Out:
# 1656    16
# 752      2
# 892     10
# 1041     1
# 1179    12
#         ..
# 1638    16
# 1095     1
# 1130    12
# 1294     7
# 860     10
# Name: Crop, Length: 1760, dtype: int64

# %% [markdown]
# **use random forest, cause  it's best :)**

# %%
# prompt: use random forest then accurecy

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Create a Random Forest classifier
clf = RandomForestClassifier()

# Train the classifier
clf.fit(x_train, y_train)

# Predict the labels for the test data
y_pred = clf.predict(x_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9931818181818182

# %% [markdown]
# **use NN**

# %%
# Import the necessary libraries
import tensorflow as tf

# Define the neural network model
model = tf.keras.Sequential([
  tf.keras.layers.Dense(128, activation='relu', input_shape=(len(x_train[0]),)),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(16, activation='relu'),
  tf.keras.layers.Dense(len(d['Crop'].value_counts()), activation='softmax')
])

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
hist=model.fit(x_train, y_train, epochs=100,validation_data=(x_test, y_test))

# Evaluate the model
accuracy = model.evaluate(x_test, y_test)[1]

# Print the accuracy
print("Accuracy:", accuracy)
# Out:
# Epoch 1/100
# 55/55 [==============================] - 1s 8ms/step - loss: 2.8466 - accuracy: 0.1528 - val_loss: 2.4755 - val_accuracy: 0.3091
# Epoch 2/100
# 55/55 [==============================] - 0s 3ms/step - loss: 1.9391 - accuracy: 0.4148 - val_loss: 1.3927 - val_accuracy: 0.5364
# Epoch 3/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.9424 - accuracy: 0.7199 - val_loss: 0.6242 - val_accuracy: 0.8386
# Epoch 4/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.4369 - accuracy: 0.8926 - val_loss: 0.3811 - val_accuracy: 0.8841
# Epoch 5/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.2787 - accuracy: 0.9244 - val_loss: 0.2924 - val_accuracy: 0.9114
# Epoch 6/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.2009 - accuracy: 0.9438 - val_loss: 0.2401 - val_accuracy: 0.9205
# Epoch 7/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1601 - accuracy: 0.9517 - val_loss: 0.2086 - val_accuracy: 0.9250
# Epoch 8/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1306 - accuracy: 0.9614 - val_loss: 0.2036 - val_accuracy: 0.9318
# Epoch 9/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1161 - accuracy: 0.9636 - val_loss: 0.1742 - val_accuracy: 0.9318
# Epoch 10/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0975 - accuracy: 0.9659 - val_loss: 0.1703 - val_accuracy: 0.9432
# Epoch 11/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0927 - accuracy: 0.9688 - val_loss: 0.1774 - val_accuracy: 0.9409
# Epoch 12/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0960 - accuracy: 0.9693 - val_loss: 0.1830 - val_accuracy: 0.9364
# Epoch 13/100
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9710 - val_loss: 0.1847 - val_accuracy: 0.9295
# Epoch 14/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0717 - accuracy: 0.9784 - val_loss: 0.1356 - val_accuracy: 0.9523
# Epoch 15/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0669 - accuracy: 0.9733 - val_loss: 0.1481 - val_accuracy: 0.9523
# Epoch 16/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0712 - accuracy: 0.9733 - val_loss: 0.1404 - val_accuracy: 0.9455
# Epoch 17/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0592 - accuracy: 0.9790 - val_loss: 0.1578 - val_accuracy: 0.9500
# Epoch 18/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9790 - val_loss: 0.1292 - val_accuracy: 0.9614
# Epoch 19/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0525 - accuracy: 0.9835 - val_loss: 0.1285 - val_accuracy: 0.9545
# Epoch 20/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 0.9852 - val_loss: 0.1302 - val_accuracy: 0.9636
# Epoch 21/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0527 - accuracy: 0.9795 - val_loss: 0.1061 - val_accuracy: 0.9636
# Epoch 22/100
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0455 - accuracy: 0.9835 - val_loss: 0.1133 - val_accuracy: 0.9659
# Epoch 23/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.9841 - val_loss: 0.1113 - val_accuracy: 0.9545
# Epoch 24/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0415 - accuracy: 0.9869 - val_loss: 0.1073 - val_accuracy: 0.9682
# Epoch 25/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9881 - val_loss: 0.1035 - val_accuracy: 0.9705
# Epoch 26/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 0.9903 - val_loss: 0.1273 - val_accuracy: 0.9614
# Epoch 27/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 0.9875 - val_loss: 0.1316 - val_accuracy: 0.9591
# Epoch 28/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0360 - accuracy: 0.9864 - val_loss: 0.1335 - val_accuracy: 0.9568
# Epoch 29/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0437 - accuracy: 0.9841 - val_loss: 0.0968 - val_accuracy: 0.9682
# Epoch 30/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0308 - accuracy: 0.9909 - val_loss: 0.1084 - val_accuracy: 0.9659
# Epoch 31/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0411 - accuracy: 0.9864 - val_loss: 0.1275 - val_accuracy: 0.9682
# Epoch 32/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0281 - accuracy: 0.9909 - val_loss: 0.1184 - val_accuracy: 0.9727
# Epoch 33/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0311 - accuracy: 0.9903 - val_loss: 0.1188 - val_accuracy: 0.9682
# Epoch 34/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0264 - accuracy: 0.9898 - val_loss: 0.0942 - val_accuracy: 0.9750
# Epoch 35/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0227 - accuracy: 0.9926 - val_loss: 0.0940 - val_accuracy: 0.9682
# Epoch 36/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0248 - accuracy: 0.9920 - val_loss: 0.0883 - val_accuracy: 0.9727
# Epoch 37/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0281 - accuracy: 0.9898 - val_loss: 0.1422 - val_accuracy: 0.9636
# Epoch 38/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0351 - accuracy: 0.9875 - val_loss: 0.1151 - val_accuracy: 0.9705
# Epoch 39/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0281 - accuracy: 0.9892 - val_loss: 0.1295 - val_accuracy: 0.9659
# Epoch 40/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 0.9858 - val_loss: 0.1266 - val_accuracy: 0.9614
# Epoch 41/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 0.9881 - val_loss: 0.1470 - val_accuracy: 0.9636
# Epoch 42/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0611 - accuracy: 0.9807 - val_loss: 0.1557 - val_accuracy: 0.9659
# Epoch 43/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 0.9909 - val_loss: 0.1002 - val_accuracy: 0.9705
# Epoch 44/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 0.9909 - val_loss: 0.1237 - val_accuracy: 0.9682
# Epoch 45/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9943 - val_loss: 0.1081 - val_accuracy: 0.9705
# Epoch 46/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9909 - val_loss: 0.1023 - val_accuracy: 0.9705
# Epoch 47/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.1133 - val_accuracy: 0.9705
# Epoch 48/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9943 - val_loss: 0.0987 - val_accuracy: 0.9682
# Epoch 49/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9937 - val_loss: 0.1118 - val_accuracy: 0.9705
# Epoch 50/100
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9926 - val_loss: 0.0957 - val_accuracy: 0.9705
# Epoch 51/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9943 - val_loss: 0.1067 - val_accuracy: 0.9727
# Epoch 52/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9915 - val_loss: 0.1275 - val_accuracy: 0.9659
# Epoch 53/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9949 - val_loss: 0.1216 - val_accuracy: 0.9705
# Epoch 54/100
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 0.9909 - val_loss: 0.0848 - val_accuracy: 0.9773
# Epoch 55/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.1055 - val_accuracy: 0.9705
# Epoch 56/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9932 - val_loss: 0.0988 - val_accuracy: 0.9727
# Epoch 57/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.0861 - val_accuracy: 0.9705
# Epoch 58/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9966 - val_loss: 0.1068 - val_accuracy: 0.9636
# Epoch 59/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9943 - val_loss: 0.0950 - val_accuracy: 0.9750
# Epoch 60/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9932 - val_loss: 0.0925 - val_accuracy: 0.9750
# Epoch 61/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 0.9926 - val_loss: 0.0873 - val_accuracy: 0.9727
# Epoch 62/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9972 - val_loss: 0.1098 - val_accuracy: 0.9682
# Epoch 63/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9937 - val_loss: 0.1016 - val_accuracy: 0.9705
# Epoch 64/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 0.9949 - val_loss: 0.0967 - val_accuracy: 0.9682
# Epoch 65/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9949 - val_loss: 0.0884 - val_accuracy: 0.9773
# Epoch 66/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.0994 - val_accuracy: 0.9795
# Epoch 67/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 0.1194 - val_accuracy: 0.9682
# Epoch 68/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.1035 - val_accuracy: 0.9682
# Epoch 69/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 0.1093 - val_accuracy: 0.9727
# Epoch 70/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.1333 - val_accuracy: 0.9682
# Epoch 71/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 0.9915 - val_loss: 0.1221 - val_accuracy: 0.9705
# Epoch 72/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9881 - val_loss: 0.1183 - val_accuracy: 0.9727
# Epoch 73/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9915 - val_loss: 0.0930 - val_accuracy: 0.9750
# Epoch 74/100
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9926 - val_loss: 0.1168 - val_accuracy: 0.9727
# Epoch 75/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9983 - val_loss: 0.1187 - val_accuracy: 0.9705
# Epoch 76/100
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0935 - val_accuracy: 0.9705
# Epoch 77/100
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9960 - val_loss: 0.1165 - val_accuracy: 0.9750
# Epoch 78/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.1202 - val_accuracy: 0.9727
# Epoch 79/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9920 - val_loss: 0.1109 - val_accuracy: 0.9659
# Epoch 80/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 0.9943 - val_loss: 0.0985 - val_accuracy: 0.9727
# Epoch 81/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.1004 - val_accuracy: 0.9705
# Epoch 82/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.1091 - val_accuracy: 0.9727
# Epoch 83/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0099 - accuracy: 0.9960 - val_loss: 0.1215 - val_accuracy: 0.9750
# Epoch 84/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9966 - val_loss: 0.1102 - val_accuracy: 0.9727
# Epoch 85/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9977 - val_loss: 0.1099 - val_accuracy: 0.9682
# Epoch 86/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9960 - val_loss: 0.1340 - val_accuracy: 0.9727
# Epoch 87/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9949 - val_loss: 0.1086 - val_accuracy: 0.9727
# Epoch 88/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.1389 - val_accuracy: 0.9682
# Epoch 89/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.1114 - val_accuracy: 0.9682
# Epoch 90/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.1376 - val_accuracy: 0.9705
# Epoch 91/100
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9955 - val_loss: 0.1117 - val_accuracy: 0.9750
# Epoch 92/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.1207 - val_accuracy: 0.9727
# Epoch 93/100
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.1250 - val_accuracy: 0.9705
# Epoch 94/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9977 - val_loss: 0.1096 - val_accuracy: 0.9750
# Epoch 95/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9972 - val_loss: 0.1210 - val_accuracy: 0.9682
# Epoch 96/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9955 - val_loss: 0.1245 - val_accuracy: 0.9727
# Epoch 97/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 0.9949 - val_loss: 0.1138 - val_accuracy: 0.9682
# Epoch 98/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.1349 - val_accuracy: 0.9682
# Epoch 99/100
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.1197 - val_accuracy: 0.9773
# Epoch 100/100
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9972 - val_loss: 0.1268 - val_accuracy: 0.9682
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9682
# Accuracy: 0.9681817889213562

# %% [markdown]
# **the accuracy is 99%... so it's perfect**

# %%
pd.DataFrame(hist.history).plot()
# Out:
# <Axes: >

# %%
#  save the model

model.save('crop_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
